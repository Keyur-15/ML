# %%
import numpy as np

import pandas as pd
 
import matplotlib.pyplot as plt
 
import statsmodels.api as sm
 
import seaborn
 
seaborn.set()

# %%
df = pd.read_csv("C:/Users/aayushi/Desktop/Kashish sem-6/ML/Practical-2/Housing.csv" )
df.head()
# Out:
#    Unnamed: 0    price  lotsize  bedrooms  bathrms  stories driveway recroom  \
# 0           1  42000.0     5850         3        1        2      yes      no
# 1           2  38500.0     4000         2        1        1      yes      no
# 2           3  49500.0     3060         3        1        1      yes      no
# 3           4  60500.0     6650         3        1        2      yes     yes
# 4           5  61000.0     6360         2        1        1      yes      no
#
#   fullbase gashw airco  garagepl prefarea
# 0      yes    no    no         1       no
# 1       no    no    no         0       no
# 2       no    no    no         0       no
# 3       no    no    no         0       no
# 4       no    no    no         0       no

# %%
x1= df[['lotsize']]

y=df[['price']]

# %%
x = sm.add_constant(x1)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.287
# Model:                            OLS   Adj. R-squared:                  0.286
# Method:                 Least Squares   F-statistic:                     219.1
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):           6.77e-42
# Time:                        21:55:14   Log-Likelihood:                -6247.0
# No. Observations:                 546   AIC:                         1.250e+04
# Df Residuals:                     544   BIC:                         1.251e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.414e+04   2491.064     13.703      0.000    2.92e+04     3.9e+04
# ...

# %%
x2= df[['bedrooms']]

y=df[['price']]

# %%
x = sm.add_constant(x2)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.134
# Model:                            OLS   Adj. R-squared:                  0.133
# Method:                 Least Squares   F-statistic:                     84.38
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):           8.53e-19
# Time:                        21:55:14   Log-Likelihood:                -6300.0
# No. Observations:                 546   AIC:                         1.260e+04
# Df Residuals:                     544   BIC:                         1.261e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.877e+04   4413.753      6.519      0.000    2.01e+04    3.74e+04
# ...

# %%
x3= df[['bathrms']]

y=df[['price']]

# %%
x = sm.add_constant(x3)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.267
# Model:                            OLS   Adj. R-squared:                  0.266
# Method:                 Least Squares   F-statistic:                     198.2
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):           1.34e-38
# Time:                        21:55:14   Log-Likelihood:                -6254.6
# No. Observations:                 546   AIC:                         1.251e+04
# Df Residuals:                     544   BIC:                         1.252e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.279e+04   2693.939     12.173      0.000    2.75e+04    3.81e+04
# ...

# %%
x4= df[['stories']]

y=df[['price']]

# %%
x = sm.add_constant(x4)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.177
# Model:                            OLS   Adj. R-squared:                  0.176
# Method:                 Least Squares   F-statistic:                     117.3
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):           6.87e-25
# Time:                        21:55:15   Log-Likelihood:                -6286.0
# No. Observations:                 546   AIC:                         1.258e+04
# Df Residuals:                     544   BIC:                         1.258e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        4.47e+04   2398.000     18.642      0.000       4e+04    4.94e+04
# ...

# %%
dummy=pd.get_dummies(df['driveway'])
dummy.head()
# Out:
#    no  yes
# 0   0    1
# 1   0    1
# 2   0    1
# 3   0    1
# 4   0    1

# %%
df1=pd.concat((df,dummy),axis=1)

# %%
df1.head()
# Out:
#    Unnamed: 0    price  lotsize  bedrooms  bathrms  stories driveway recroom  \
# 0           1  42000.0     5850         3        1        2      yes      no
# 1           2  38500.0     4000         2        1        1      yes      no
# 2           3  49500.0     3060         3        1        1      yes      no
# 3           4  60500.0     6650         3        1        2      yes     yes
# 4           5  61000.0     6360         2        1        1      yes      no
#
#   fullbase gashw airco  garagepl prefarea  no  yes
# 0      yes    no    no         1       no   0    1
# 1       no    no    no         0       no   0    1
# 2       no    no    no         0       no   0    1
# 3       no    no    no         0       no   0    1
# 4       no    no    no         0       no   0    1

# %%
df1=df1.drop(['driveway','no'],axis=1)
df1.head()
df1.rename(columns={"yes":"driveway"})
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories recroom  \
# 0             1   42000.0     5850         3        1        2      no
# 1             2   38500.0     4000         2        1        1      no
# 2             3   49500.0     3060         3        1        1      no
# 3             4   60500.0     6650         3        1        2     yes
# 4             5   61000.0     6360         2        1        1      no
# ..          ...       ...      ...       ...      ...      ...     ...
# 541         542   91500.0     4800         3        2        4     yes
# 542         543   94000.0     6000         3        2        4      no
# 543         544  103000.0     6000         3        2        4     yes
# 544         545  105000.0     6000         3        2        2     yes
# 545         546  105000.0     6000         3        1        2      no
#
#     fullbase gashw airco  garagepl prefarea  driveway
# 0        yes    no    no         1       no         1
# ...

# %%
x5= df1[['yes']]

y=df1[['price']]

# %%
x = sm.add_constant(x5)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.088
# Model:                            OLS   Adj. R-squared:                  0.087
# Method:                 Least Squares   F-statistic:                     52.69
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):           1.35e-12
# Time:                        21:55:15   Log-Likelihood:                -6314.1
# No. Observations:                 546   AIC:                         1.263e+04
# Df Residuals:                     544   BIC:                         1.264e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.856e+04   2908.253     16.696      0.000    4.28e+04    5.43e+04
# ...

# %%
dummy1=pd.get_dummies(df['recroom'])
dummy1.head()
# Out:
#    no  yes
# 0   1    0
# 1   1    0
# 2   1    0
# 3   0    1
# 4   1    0

# %%
df2=pd.concat((df1,dummy1),axis=1)
df2.head()
# Out:
#    Unnamed: 0    price  lotsize  bedrooms  bathrms  stories recroom fullbase  \
# 0           1  42000.0     5850         3        1        2      no      yes
# 1           2  38500.0     4000         2        1        1      no       no
# 2           3  49500.0     3060         3        1        1      no       no
# 3           4  60500.0     6650         3        1        2     yes       no
# 4           5  61000.0     6360         2        1        1      no       no
#
#   gashw airco  garagepl prefarea  yes  no  yes
# 0    no    no         1       no    1   1    0
# 1    no    no         0       no    1   1    0
# 2    no    no         0       no    1   1    0
# 3    no    no         0       no    1   0    1
# 4    no    no         0       no    1   1    0

# %%
df2=df2.drop(['recroom','no'],axis=1)
df2.head()
df2.rename(columns={"yes":"recroom"})
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories fullbase gashw  \
# 0             1   42000.0     5850         3        1        2      yes    no
# 1             2   38500.0     4000         2        1        1       no    no
# 2             3   49500.0     3060         3        1        1       no    no
# 3             4   60500.0     6650         3        1        2       no    no
# 4             5   61000.0     6360         2        1        1       no    no
# ..          ...       ...      ...       ...      ...      ...      ...   ...
# 541         542   91500.0     4800         3        2        4       no    no
# 542         543   94000.0     6000         3        2        4       no    no
# 543         544  103000.0     6000         3        2        4       no    no
# 544         545  105000.0     6000         3        2        2       no    no
# 545         546  105000.0     6000         3        1        2       no    no
#
# ...

# %%
x6= df2[['yes']]

y=df2[['price']]

# %%
x = sm.add_constant(x6)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.141
# Model:                            OLS   Adj. R-squared:                  0.137
# Method:                 Least Squares   F-statistic:                     44.41
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):           1.38e-18
# Time:                        21:55:15   Log-Likelihood:                -6298.0
# No. Observations:                 546   AIC:                         1.260e+04
# Df Residuals:                     543   BIC:                         1.261e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        4.71e+04   2837.618     16.598      0.000    4.15e+04    5.27e+04
# ...

# %%
dummy2=pd.get_dummies(df['fullbase'])
dummy2.head()
# Out:
#    no  yes
# 0   0    1
# 1   1    0
# 2   1    0
# 3   1    0
# 4   1    0

# %%
df3=pd.concat((df2,dummy2),axis=1)
df3.head()
# Out:
#    Unnamed: 0    price  lotsize  bedrooms  bathrms  stories fullbase gashw  \
# 0           1  42000.0     5850         3        1        2      yes    no
# 1           2  38500.0     4000         2        1        1       no    no
# 2           3  49500.0     3060         3        1        1       no    no
# 3           4  60500.0     6650         3        1        2       no    no
# 4           5  61000.0     6360         2        1        1       no    no
#
#   airco  garagepl prefarea  yes  yes  no  yes
# 0    no         1       no    1    0   0    1
# 1    no         0       no    1    0   1    0
# 2    no         0       no    1    0   1    0
# 3    no         0       no    1    1   1    0
# 4    no         0       no    1    0   1    0

# %%
df3=df3.drop(['fullbase','no'],axis=1)
df3.head()
df3.rename(columns={"yes":"fullbase"})
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories gashw airco  \
# 0             1   42000.0     5850         3        1        2    no    no
# 1             2   38500.0     4000         2        1        1    no    no
# 2             3   49500.0     3060         3        1        1    no    no
# 3             4   60500.0     6650         3        1        2    no    no
# 4             5   61000.0     6360         2        1        1    no    no
# ..          ...       ...      ...       ...      ...      ...   ...   ...
# 541         542   91500.0     4800         3        2        4    no   yes
# 542         543   94000.0     6000         3        2        4    no   yes
# 543         544  103000.0     6000         3        2        4    no   yes
# 544         545  105000.0     6000         3        2        2    no   yes
# 545         546  105000.0     6000         3        1        2    no   yes
#
#      garagepl prefarea  fullbase  fullbase  fullbase
# ...

# %%
x7= df3[['yes']]

y=df3[['price']]

# %%
x = sm.add_constant(x7)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.150
# Model:                            OLS   Adj. R-squared:                  0.145
# Method:                 Least Squares   F-statistic:                     31.81
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):           5.95e-19
# Time:                        21:55:16   Log-Likelihood:                -6295.1
# No. Observations:                 546   AIC:                         1.260e+04
# Df Residuals:                     542   BIC:                         1.262e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.562e+04   2890.730     15.782      0.000    3.99e+04    5.13e+04
# ...

# %%
dummy3=pd.get_dummies(df['gashw'])
dummy3.head()
# Out:
#    no  yes
# 0   1    0
# 1   1    0
# 2   1    0
# 3   1    0
# 4   1    0

# %%
df4=pd.concat((df3,dummy3),axis=1)
df4.head()
# Out:
#    Unnamed: 0    price  lotsize  bedrooms  bathrms  stories gashw airco  \
# 0           1  42000.0     5850         3        1        2    no    no
# 1           2  38500.0     4000         2        1        1    no    no
# 2           3  49500.0     3060         3        1        1    no    no
# 3           4  60500.0     6650         3        1        2    no    no
# 4           5  61000.0     6360         2        1        1    no    no
#
#    garagepl prefarea  yes  yes  yes  no  yes
# 0         1       no    1    0    1   1    0
# 1         0       no    1    0    0   1    0
# 2         0       no    1    0    0   1    0
# 3         0       no    1    1    0   1    0
# 4         0       no    1    0    0   1    0

# %%
df4=df4.drop(['gashw','no'],axis=1)
df4.head()
df4.rename(columns={"yes":"gashw"})
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories airco  \
# 0             1   42000.0     5850         3        1        2    no
# 1             2   38500.0     4000         2        1        1    no
# 2             3   49500.0     3060         3        1        1    no
# 3             4   60500.0     6650         3        1        2    no
# 4             5   61000.0     6360         2        1        1    no
# ..          ...       ...      ...       ...      ...      ...   ...
# 541         542   91500.0     4800         3        2        4   yes
# 542         543   94000.0     6000         3        2        4   yes
# 543         544  103000.0     6000         3        2        4   yes
# 544         545  105000.0     6000         3        2        2   yes
# 545         546  105000.0     6000         3        1        2   yes
#
#      garagepl prefarea  gashw  gashw  gashw  gashw
# 0           1       no      1      0      1      0
# ...

# %%
x8= df4[['yes']]

y=df4[['price']]

# %%
x = sm.add_constant(x8)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.159
# Model:                            OLS   Adj. R-squared:                  0.153
# Method:                 Least Squares   F-statistic:                     25.61
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):           1.86e-19
# Time:                        21:55:16   Log-Likelihood:                -6292.0
# No. Observations:                 546   AIC:                         1.259e+04
# Df Residuals:                     541   BIC:                         1.262e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.498e+04   2888.702     15.572      0.000    3.93e+04    5.07e+04
# ...

# %%
dummy4=pd.get_dummies(df['airco'])
dummy4.head()
# Out:
#    no  yes
# 0   1    0
# 1   1    0
# 2   1    0
# 3   1    0
# 4   1    0

# %%
df5=pd.concat((df4,dummy4),axis=1)
df5.head()
# Out:
#    Unnamed: 0    price  lotsize  bedrooms  bathrms  stories airco  garagepl  \
# 0           1  42000.0     5850         3        1        2    no         1
# 1           2  38500.0     4000         2        1        1    no         0
# 2           3  49500.0     3060         3        1        1    no         0
# 3           4  60500.0     6650         3        1        2    no         0
# 4           5  61000.0     6360         2        1        1    no         0
#
#   prefarea  yes  yes  yes  yes  no  yes
# 0       no    1    0    1    0   1    0
# 1       no    1    0    0    0   1    0
# 2       no    1    0    0    0   1    0
# 3       no    1    1    0    0   1    0
# 4       no    1    0    0    0   1    0

# %%
df5=df5.drop(['airco','no'],axis=1)
df5.head()
df5.rename(columns={"yes":"airco"})
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories  garagepl  \
# 0             1   42000.0     5850         3        1        2         1
# 1             2   38500.0     4000         2        1        1         0
# 2             3   49500.0     3060         3        1        1         0
# 3             4   60500.0     6650         3        1        2         0
# 4             5   61000.0     6360         2        1        1         0
# ..          ...       ...      ...       ...      ...      ...       ...
# 541         542   91500.0     4800         3        2        4         0
# 542         543   94000.0     6000         3        2        4         0
# 543         544  103000.0     6000         3        2        4         1
# 544         545  105000.0     6000         3        2        2         1
# 545         546  105000.0     6000         3        1        2         1
#
#     prefarea  airco  airco  airco  airco  airco
# ...

# %%
x9= df5[['yes']]

y=df5[['price']]

# %%
x = sm.add_constant(x9)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.331
# Model:                            OLS   Adj. R-squared:                  0.325
# Method:                 Least Squares   F-statistic:                     53.55
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):           3.94e-45
# Time:                        21:55:16   Log-Likelihood:                -6229.4
# No. Observations:                 546   AIC:                         1.247e+04
# Df Residuals:                     540   BIC:                         1.250e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.018e+04   2610.167     15.395      0.000    3.51e+04    4.53e+04
# ...

# %%
x10= df[['garagepl']]

y=df[['price']]

# %%
x = sm.add_constant(x10)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.147
# Model:                            OLS   Adj. R-squared:                  0.145
# Method:                 Least Squares   F-statistic:                     93.69
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):           1.50e-20
# Time:                        21:55:16   Log-Likelihood:                -6296.0
# No. Observations:                 546   AIC:                         1.260e+04
# Df Residuals:                     544   BIC:                         1.260e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.989e+04   1355.917     44.173      0.000    5.72e+04    6.26e+04
# ...

# %%
dummy5=pd.get_dummies(df['prefarea'])
dummy5.head()
# Out:
#    no  yes
# 0   1    0
# 1   1    0
# 2   1    0
# 3   1    0
# 4   1    0

# %%
df6=pd.concat((df5,dummy5),axis=1)
df6.head()
# Out:
#    Unnamed: 0    price  lotsize  bedrooms  bathrms  stories  garagepl  \
# 0           1  42000.0     5850         3        1        2         1
# 1           2  38500.0     4000         2        1        1         0
# 2           3  49500.0     3060         3        1        1         0
# 3           4  60500.0     6650         3        1        2         0
# 4           5  61000.0     6360         2        1        1         0
#
#   prefarea  yes  yes  yes  yes  yes  no  yes
# 0       no    1    0    1    0    0   1    0
# 1       no    1    0    0    0    0   1    0
# 2       no    1    0    0    0    0   1    0
# 3       no    1    1    0    0    0   1    0
# 4       no    1    0    0    0    0   1    0

# %%
df6=df6.drop(['prefarea','no'],axis=1)
df6.head()
df6.rename(columns={"yes":"prefarea"})
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories  garagepl  \
# 0             1   42000.0     5850         3        1        2         1
# 1             2   38500.0     4000         2        1        1         0
# 2             3   49500.0     3060         3        1        1         0
# 3             4   60500.0     6650         3        1        2         0
# 4             5   61000.0     6360         2        1        1         0
# ..          ...       ...      ...       ...      ...      ...       ...
# 541         542   91500.0     4800         3        2        4         0
# 542         543   94000.0     6000         3        2        4         0
# 543         544  103000.0     6000         3        2        4         1
# 544         545  105000.0     6000         3        2        2         1
# 545         546  105000.0     6000         3        1        2         1
#
#      prefarea  prefarea  prefarea  prefarea  prefarea  prefarea
# ...

# %%
x11= df6[['yes']]

y=df6[['price']]

# %%
x = sm.add_constant(x11)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.374
# Model:                            OLS   Adj. R-squared:                  0.367
# Method:                 Least Squares   F-statistic:                     53.68
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):           7.67e-52
# Time:                        21:55:17   Log-Likelihood:                -6211.5
# No. Observations:                 546   AIC:                         1.244e+04
# Df Residuals:                     539   BIC:                         1.247e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.073e+04   2529.634     16.102      0.000    3.58e+04    4.57e+04
# ...

# %%
x12= df[['lotsize','bathrms','bedrooms']]

y=df[['price']]

# %%
x = sm.add_constant(x12)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.486
# Model:                            OLS   Adj. R-squared:                  0.483
# Method:                 Least Squares   F-statistic:                     171.0
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):           5.22e-78
# Time:                        21:55:17   Log-Likelihood:                -6157.5
# No. Observations:                 546   AIC:                         1.232e+04
# Df Residuals:                     542   BIC:                         1.234e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2418.2926   3779.412     -0.640      0.523   -9842.383    5005.798
# ...

# %%
x13= df[['lotsize','bathrms','stories']]

y=df[['price']]

# %%
x = sm.add_constant(x13)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.531
# Model:                            OLS   Adj. R-squared:                  0.528
# Method:                 Least Squares   F-statistic:                     204.5
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):           1.11e-88
# Time:                        21:55:17   Log-Likelihood:                -6132.7
# No. Observations:                 546   AIC:                         1.227e+04
# Df Residuals:                     542   BIC:                         1.229e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1245.4329   2817.543      0.442      0.659   -4289.209    6780.074
# ...

# %%
x14= df[['lotsize','bedrooms','bathrms','stories','garagepl']]

y=df[['price']]

# %%
x = sm.add_constant(x14)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.561
# Model:                            OLS   Adj. R-squared:                  0.557
# Method:                 Least Squares   F-statistic:                     138.2
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):           3.38e-94
# Time:                        21:55:17   Log-Likelihood:                -6114.4
# No. Observations:                 546   AIC:                         1.224e+04
# Df Residuals:                     540   BIC:                         1.227e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2063.6401   3521.887     -0.586      0.558   -8981.919    4854.639
# ...

# %%
x15= df6[['lotsize','bedrooms','bathrms','stories','garagepl','yes','yes','yes','yes','yes','yes']]

y=df6[['price']]

# %%
x = sm.add_constant(x15)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.673
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     99.97
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):          6.18e-122
# Time:                        21:55:17   Log-Likelihood:                -6034.1
# No. Observations:                 546   AIC:                         1.209e+04
# Df Residuals:                     534   BIC:                         1.214e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -4038.3504   3409.471     -1.184      0.237   -1.07e+04    2659.271
# ...
